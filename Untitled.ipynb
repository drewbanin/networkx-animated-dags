# %%
# %matplotlib inline

import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML, Image

rc('animation', html='html5')

# %%
graph = nx.Graph()
graph.add_node(0, Position=(random.randrange(0, 100), random.randrange(0, 100)))

# Build plot
fig, ax = plt.subplots(figsize=(6,4))

def update(i):
    ax.clear()
    
    graph.add_node(i, Position=(random.randrange(0, 100), random.randrange(0, 100)))
    graph.add_edge(i, random.choice(list(graph.nodes.keys())))
    nx.draw(graph, pos=nx.get_node_attributes(graph, 'Position'), ax=ax)

    # Scale plot ax
    ax.set_title("Step {}".format(i))
    ax.set_xticks([])
    ax.set_yticks([])


ani = matplotlib.animation.FuncAnimation(fig, update, frames=6, interval=1000, repeat=True)

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img375c085d43ed4060aa31ffd0cae23bf9">
#     <br>
#     <input id="_anim_slider375c085d43ed4060aa31ffd0cae23bf9" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim375c085d43ed4060aa31ffd0cae23bf9.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim375c085d43ed4060aa31ffd0cae23bf9.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select375c085d43ed4060aa31ffd0cae23bf9" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img375c085d43ed4060aa31ffd0cae23bf9";
#     var slider_id = "_anim_slider375c085d43ed4060aa31ffd0cae23bf9";
#     var loop_select_id = "_anim_loop_select375c085d43ed4060aa31ffd0cae23bf9";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAACbtJREFUeJzt3U2IlWUfx/H/0cBGnTcZc5LIoAgn\
# SxclTS9gRYRZtCuIoqZgwnYFBhVEryRB1lKpzbiIonUk7YyECFvkG5m1yWbMnGBGMy0351kcnOfx\
# 0WiyM9rPPp/dOed+ue7Vl+v28ppGs9lsFgCEmXW+BwAAZ0PAAIgkYABEEjAAIgkYAJEEDIBIAgZA\
# JAEDIJKAARBJwACIJGAARBIwACIJGACRBAyASAIGQCQBAyCSgAEQScAAiCRgAEQSMJimbdu21c03\
# 31zd3d21YMGCuuWWW2r79u1VVTUyMlK33nrrjN37999/r8cff7y6urqqv7+/3nrrrRm7F6S46HwP\
# ABIcOXKk7r333tq4cWM98MADdeLEifrss89qzpw55+T+L730Un377bf1/fff18GDB+v222+va665\
# plavXn1O7g//RGZgMA379u2rqqoHH3ywZs+eXR0dHXXXXXfV8uXL6+uvv661a9fW559/XvPnz6+e\
# np6qas2a1q1bV5dffnktWrSo1q5dW8ePH6+qqq1bt9Zll11Wr7/+evX19dUVV1xR77333h/ef/Pm\
# zfXCCy9Ub29vDQwM1PDwcI2MjMz4c8M/mYDBNFx99dU1e/bsevTRR2vLli01MTEx9dvAwEBt2rSp\
# brrppjp69GhNTk5WVdWzzz5b+/btq6+++qq+++67Ghsbq1deeWXqvIMHD9bPP/9cY2NjtXnz5nri\
# iSfqm2++Oe3eExMT9eOPP9aKFSumvluxYkXt2bNnBp8Y/vkEDKahq6urtm3bVo1Go4aHh2vhwoV1\
# 33331U8//XTG45vNZr3zzjv19ttv14IFC6qzs7Oef/75+uCDD0457tVXX605c+bUqlWr6p577qkP\
# P/zwtGsdPXq0qqq6u7unvuvu7q5ffvmljU8IeQQMpmlgYKBGRkZqdHS0du/eXQcOHKinnnrqjMeO\
# j4/XsWPH6vrrr6+enp7q6emp1atX1/j4+NQxvb29NW/evKnPS5YsqQMHDpx2rfnz51dV69/hTjpy\
# 5Eh1dna269EgkoDBWVi6dGkNDQ3V7t27q6qq0Wic8ntfX191dHTUnj17anJysiYnJ+vw4cNTs6mq\
# 1qvBX3/9derz/v37a/Hixafdq7e3ty699NLasWPH1Hc7duyoZcuWtfuxIIqAwTTs3bu3NmzYUKOj\
# o1VV9cMPP9T7779fg4ODVVW1aNGiGh0drRMnTlRV1axZs2p4eLiefvrpOnToUFVVjY2N1SeffHLK\
# dV988cWpFY0fffRR3X///We8/yOPPFKvvfZaTUxM1N69e+vdd9+toaGhGXpayCBgMA2dnZ31xRdf\
# 1I033ljz5s2rwcHBuvbaa2vDhg1VVXXHHXfUsmXLqr+/v/r6+qqq6o033qirrrqqBgcHq6urq+68\
# 885TFmn09/dXb29vLV68uB566KHatGlTLV269Iz3f/nll+vKK6+sJUuW1KpVq+qZZ56xhJ5/vUaz\
# 2Wye70HAv83WrVvr4YcfnprRAX+dGRgAkQQMgEheIQIQyQwMgEgCBkAkAQMgkoABEEnAAIgkYABE\
# EjAAIgkYAJEEDIBIAgZAJAEDIJKAARBJwACIJGAARBIwACIJGACRBAyASAIGQCQBAyCSgAEQScAA\
# iCRgAEQSMAAiCRgAkQQMgEgCBkAkAQMgkoABEEnAAIgkYABEEjAAIgkYAJEEDIBIAgZAJAEDIJKA\
# ARBJwACIJGAARBIwACIJGACRBAyASAIGQCQBAyCSgAEQScAAiCRgAEQSMAAiCRgAkQQMgEgCBkAk\
# AQMgkoABEEnAAIgkYABEEjAAIgkYAJEEDIBIAgZAJAEDIJKAARBJwACIJGAARBIwA
